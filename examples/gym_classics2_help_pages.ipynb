# %% [markdown]
# # Help With `gym_classics2`
#
# This file contains help pages for the `gym_classics2` package. The code is available
# at https://github.com/mhahsler/gym-classics2

# %%
import gymnasium as gym
import gym_classics2
gym_classics2.register('gymnasium')

# %% [markdown]
# # Environments

# %% [markdown]
# ## The Gymnasium Base Environment
#
# This class defines the basic methods for all Gymnasium compatible environments.

# %%
help(gym.Env)
# Out:
# Help on class Env in module gymnasium.core:
#
# class Env(typing.Generic)
#  |  The main Gymnasium class for implementing Reinforcement Learning Agents environments.
#  |
#  |  The class encapsulates an environment with arbitrary behind-the-scenes dynamics through the :meth:`step` and :meth:`reset` functions.
#  |  An environment can be partially or fully observed by single agents. For multi-agent environments, see PettingZoo.
#  |
#  |  The main API methods that users of this class need to know are:
#  |
#  |  - :meth:`step` - Updates an environment with actions returning the next agent observation, the reward for taking that actions,
#  |    if the environment has terminated or truncated due to the latest action and information from the environment about the step, i.e. metrics, debug info.
#  |  - :meth:`reset` - Resets the environment to an initial state, required before calling step.
# ...

# %% [markdown]
# ## gym_classics2 BaseEnv class
#
# `gym_classic2` environments have model access and extend the Gymnasium environment interface defined in the
# abstract `BaseEnv` class.
#
# Source code: [`gym_classics2.envs.abstract.base_env`](https://github.com/mhahsler/gym-classics2/tree/main/gym_classics2/envs)
#
# ### Public Interface

# %%
from gym_classics2.envs.abstract.base_env import BaseEnv

help(BaseEnv)
# Out:
# Help on class BaseEnv in module gym_classics2.envs.abstract.base_env:
#
# class BaseEnv(gymnasium.core.Env)
#  |  BaseEnv(starts, action_labels=None, tabular=True, reachable_states=None)
#  |
#  |  Abstract base class for shared functionality between all environments.
#  |
#  |  Method resolution order:
#  |      BaseEnv
#  |      gymnasium.core.Env
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, starts, action_labels=None, tabular=True, reachable_states=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  action2id(self, action_label)
#  |      Converts a action label into a numeric action ID.
#  |
#  |  actions(self)
#  |      Returns a generator over all possible agent actions.
#  |
#  |  id2action(self, action, type='text')
#  |      Converts a numeric action ID into a label. Choices for type are 'text' and 'arrow'.
#  |
#  |  id2state(self, i)
# ...

# %% [markdown]
# ### Important Internal Methods
#
# To create a gym-classic environment that behaves differently than the standard environment, you will need to overwrite some of these
# internal methods.

# %%
from gym_classics2.envs.abstract.base_env import BaseEnv

help(BaseEnv.__init__)
help(BaseEnv._next_state)
help(BaseEnv._reward)
help(BaseEnv._done)
# Out:
# Help on function __init__ in module gym_classics2.envs.abstract.base_env:
#
# __init__(self, starts, action_labels=None, tabular=True, reachable_states=None)
#     Initialize self.  See help(type(self)) for accurate signature.
#
# Help on function _next_state in module gym_classics2.envs.abstract.base_env:
#
# _next_state(self, state, action, *random_elements)
#     Returns the next state S' induced by the state-action pair (S, A), which must
#     be deterministic conditioned on the values of any random_elements. Also returns
#     the probability that this particular transition occurred.
#
# Help on function _reward in module gym_classics2.envs.abstract.base_env:
#
# _reward(self, state, action, next_state)
#     Returns the reward yielded by this (S,A,S') outcome.
#
# Help on function _done in module gym_classics2.envs.abstract.base_env:
#
# _done(self, state, action, next_state)
#     Returns True if this (S,A,S') outcome should terminate, False otherwise.

# %% [markdown]
# **Note:** the `*` in front of `*random_elements` means that the method accepts a arbitrary number of positional arguments. If there are no
# random elements, then this is just ignored.

# %% [markdown]
# ## The Abstract Gridworld Class
#
# This is the base class to extend for creating a new Gridworld.
#
# Souce code: [`gym_classics2.envs.abstract.gridworld`](https://github.com/mhahsler/gym-classics/blob/main/gym_classics2/envs/abstract/gridworld.py)

# %%
from gym_classics2.envs.abstract.gridworld import Gridworld

help(Gridworld)
# Out:
# Help on class Gridworld in module gym_classics2.envs.abstract.gridworld:
#
# class Gridworld(gym_classics2.envs.abstract.base_env.BaseEnv)
#  |  Gridworld(layout_string, action_labels=['up', 'right', 'down', 'left'], goal_reward=1.0, step_reward=0.0, tabular=True, render_mode=None)
#  |
#  |  Abstract class for creating gridworld-type environments.
#  |
#  |  Method resolution order:
#  |      Gridworld
#  |      gym_classics2.envs.abstract.base_env.BaseEnv
#  |      gymnasium.core.Env
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, layout_string, action_labels=['up', 'right', 'down', 'left'], goal_reward=1.0, step_reward=0.0, tabular=True, render_mode=None)
#  |      Initializes the gridworld environment from a layout string. The layout string should be a rectangular grid of characters, where each character represents a type of cell:
#  |      - 'S': Start (may be more than one)
# ...

# %% [markdown]
# ## Concrete Environments
#
# See section `gym-classics` in the following list.

# %%
gym.pprint_registry()
# Out:
# ===== classic_control =====
# Acrobot-v1             CartPole-v0            CartPole-v1
# MountainCar-v0         MountainCarContinuous-v0 Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0     phys2d/CartPole-v1     phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3       BipedalWalkerHardcore-v3 CarRacing-v3
# LunarLander-v3         LunarLanderContinuous-v3
# ===== toy_text =====
# Blackjack-v1           CliffWalking-v1        CliffWalkingSlippery-v1
# FrozenLake-v1          FrozenLake8x8-v1       Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0   tabular/CliffWalking-v0
# ===== None =====
# Ant-v2                 Ant-v3                 GymV21Environment-v0
# GymV26Environment-v0   HalfCheetah-v2         HalfCheetah-v3
# Hopper-v2              Hopper-v3              Humanoid-v2
# Humanoid-v3            HumanoidStandup-v2     InvertedDoublePendulum-v2
# InvertedPendulum-v2    Pusher-v2              Reacher-v2
# Swimmer-v2             Swimmer-v3             Walker2d-v2
# ...

# %% [markdown]
# The code for the environments can be found here: https://github.com/mhahsler/gym-classics/tree/main/gym_classics2/envs
#
# Here is how you get the manual page for an environment. Note that you have to unwrap the original environment.

# %%
env = gym.make("LMaze-v0")

help(env.unwrapped)
# Out:
# Help on LMazeGridworld in module gym_classics2.envs.gym_classics2.L_maze object:
#
# class LMazeGridworld(gym_classics2.envs.abstract.gridworld.Gridworld)
#  |  LMazeGridworld(**args)
#  |
#  |  Method resolution order:
#  |      LMazeGridworld
#  |      gym_classics2.envs.abstract.gridworld.Gridworld
#  |      gym_classics2.envs.abstract.base_env.BaseEnv
#  |      gymnasium.core.Env
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, **args)
#  |      Initializes the gridworld environment from a layout string. The layout string should be a rectangular grid of characters, where each character represents a type of cell:
#  |      - 'S': Start (may be more than one)
#  |      - 'G': Goal (may be more than one)
#  |      - 'X': Block (agent cannot occupy these cells)
#  |      - ' ': Empty (agent can occupy these cells)
#  |      - All other characters are treated as empty cells that the agent can occupy.
#  |
# ...

# %% [markdown]
# # Helper Functions

# %%
from gym_classics2.algorithms import policy
help(gym_classics2.algorithms.policy)
# Out:
# Help on module gym_classics2.algorithms.policy in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.policy
#
# DESCRIPTION
#     This file implements different policy representations and functions for working with policies in gym-classics environments.
#     It includes functions for creating random policies, encoding policies for display, and computing greedy policies based
#
# FUNCTIONS
#     encode_policy(env, policy, type='text')
#         Encode a policy for display. The policy is represented as a numpy array where each entry corresponds to an action for a state.
#         The function returns a list of action names corresponding to the actions in the policy.
#
#     epsilon_greedy_action(policy, state=None, epsilon=0)
#         Get an epsilon-greedy action for a given tabular policy.
#
#         :param policy: the policy as a 1-D numpy array
#         :param epsilon: the probability of taking a random action
#         :param state: the current state
#
# ...

# %%
from gym_classics2.algorithms import schedules
help(gym_classics2.algorithms.schedules)
# Out:
# Help on module gym_classics2.algorithms.schedules in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.schedules
#
# DESCRIPTION
#     This file implements different schedules to reduce the learning rate alpha or
#     the exploration rate epsilon over time (used in on-policy methods for GLIE).
#     These are commonly used in reinforcement learning algorithms
#     to improve convergence and performance.
#
# CLASSES
#     builtins.object
#         Schedule
#             ConstantSchedule
#             ExponentialDecaySchedule
#             InverseDecaySchedule
#             LinearDecaySchedule
#             StepSchedule
#
#     class ConstantSchedule(Schedule)
#      |  ConstantSchedule(value)
#      |
#      |  A schedule that always returns a constant value.
#      |
#      |  Method resolution order:
#      |      ConstantSchedule
#      |      Schedule
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, t)
# ...

# %%
from gym_classics2 import utils
help(gym_classics2.utils)
# Out:
# Help on module gym_classics2.utils in gym_classics2:
#
# NAME
#     gym_classics2.utils
#
# FUNCTIONS
#     clip(x, low, high)
#         A scalar version of numpy.clip. Much faster because it avoids memory allocation.
#
#     random_argmax(x, axis=None)
#         Argmax that breaks ties randomly. If axis is None, returns a single index.
#         If axis is specified, returns an array of indices along that axis.
#
# FILE
#     /home/mhahsler/github/Introduction_to_Reinforcement_Learning/common/gym-classics2/gym_classics2/utils.py

# %% [markdown]
# # Algorithms
#
# Code: https://github.com/mhahsler/gym-classics2/tree/main/gym_classics2/algorithms

# %% [markdown]
# ## Dynamic Programming

# %%
from gym_classics2.algorithms import dynamic_programming
help(gym_classics2.algorithms.dynamic_programming)
# Out:
# Help on module gym_classics2.algorithms.dynamic_programming in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.dynamic_programming
#
# DESCRIPTION
#     This file implements dynamic programming algorithms for solving Markov Decision Processes (MDPs)
#     in gym-classics environments with model access.
#     The algorithms include value iteration and policy iteration, which are fundamental methods in reinforcement learning for
#     computing optimal policies and value functions.
#
# FUNCTIONS
#     backup(env, discount, V, state, action)
#         Computes the Bellman backup for a given state and action.
#
#         Args:
#             env: A gym-classics environment with model access.
#             discount: The discount factor.
#             V: The current value function.
#             state: The current state.
#             action: The action to evaluate.
#         Returns:
#             The computed Q-value for the given state and action.
#
# ...

# %%
from gym_classics2.algorithms import policy
help(gym_classics2.algorithms.policy)
# Out:
# Help on module gym_classics2.algorithms.policy in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.policy
#
# DESCRIPTION
#     This file implements different policy representations and functions for working with policies in gym-classics environments.
#     It includes functions for creating random policies, encoding policies for display, and computing greedy policies based
#
# FUNCTIONS
#     encode_policy(env, policy, type='text')
#         Encode a policy for display. The policy is represented as a numpy array where each entry corresponds to an action for a state.
#         The function returns a list of action names corresponding to the actions in the policy.
#
#     epsilon_greedy_action(policy, state=None, epsilon=0)
#         Get an epsilon-greedy action for a given tabular policy.
#
#         :param policy: the policy as a 1-D numpy array
#         :param epsilon: the probability of taking a random action
#         :param state: the current state
#
# ...

# %% [markdown]
# ## Monte Carlo Methods

# %%
from gym_classics2.algorithms import monte_carlo_methods
help(gym_classics2.algorithms.monte_carlo_methods)
# Out:
# Help on module gym_classics2.algorithms.monte_carlo_methods in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.monte_carlo_methods
#
# DESCRIPTION
#     This file implements tabular Monte Carlo methods for policy evaluation and control in gym-classics environments
#     with discrete state spaces.
#
# FUNCTIONS
#     MC_control_ES(env, discount, n=100, Q=None, max_episode_len=100, history=False, verbose=False)
#         Monte Carlo Control with Exploring Starts (incremental version).
#         This algorithm estimates the optimal action-value function Q and the corresponding greedy policy by sampling episodes with exploring starts. It uses incremental updates to compute the average returns for each (s,a) pair, which is more memory efficient than storing all returns.
#         Args: env: The environment to interact with. Must have discrete state and action spaces.
#             discount: The discount factor (gamma) for future rewards. Should be in (0, 1].
# ...

# %%
from gym_classics2.algorithms import schedules
help(gym_classics2.algorithms.schedules)
# Out:
# Help on module gym_classics2.algorithms.schedules in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.schedules
#
# DESCRIPTION
#     This file implements different schedules to reduce the learning rate alpha or
#     the exploration rate epsilon over time (used in on-policy methods for GLIE).
#     These are commonly used in reinforcement learning algorithms
#     to improve convergence and performance.
#
# CLASSES
#     builtins.object
#         Schedule
#             ConstantSchedule
#             ExponentialDecaySchedule
#             InverseDecaySchedule
#             LinearDecaySchedule
#             StepSchedule
#
#     class ConstantSchedule(Schedule)
#      |  ConstantSchedule(value)
#      |
#      |  A schedule that always returns a constant value.
#      |
#      |  Method resolution order:
#      |      ConstantSchedule
#      |      Schedule
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, t)
# ...

# %% [markdown]
# ## Temporal Differencing Methods

# %%
from gym_classics2.algorithms import temporal_difference_learning
help(gym_classics2.algorithms.temporal_difference_learning)
# Out:
# Help on module gym_classics2.algorithms.temporal_difference_learning in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.temporal_difference_learning
#
# DESCRIPTION
#     This file implements temporal difference learning algorithms for policy evaluation and control in gym-classics
#     environments with discrete state spaces. The algorithms include Sarsa(0) and Q-learning, which are fundamental
#     methods in reinforcement learning for learning value functions and optimal policies from experience without requiring a
#     model of the environment.
#
# FUNCTIONS
#     Q_learning(env, discount, alpha, epsilon, Q=None, n=100, verbose=False, history=False)
#
#     Sarsa_0(env, discount, alpha, epsilon, Q=None, n=100, verbose=False, history=False)
#
# FILE
#     /home/mhahsler/github/Introduction_to_Reinforcement_Learning/common/gym-classics2/gym_classics2/algorithms/temporal_difference_learning.py

# %% [markdown]
# ## Linear Function Approximation

# %%
from gym_classics2.algorithms import linear_approximation
help(gym_classics2.algorithms.linear_approximation)
# Out:
# Help on module gym_classics2.algorithms.linear_approximation in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.linear_approximation
#
# DESCRIPTION
#     This file implements linear function approximation algorithms for policy evaluation and control. This is not a tabular approach
#     and does not require discrete state spaces. The user needs to implement the state_features function to convert states to feature
#     vectors.
#
# FUNCTIONS
#     MSVE(V, V_true, weight=None)
#         Calculate the (weighted) mean squared value error.
#
#         :param V: value function to evaluate
#         :param V_true: the value function to compare to
#         :param weight: weight for each state. Typically the stationary state visit distribution.
#
#     active_weights(a, sf_len)
#         helper for q_hat()
#
#     create_fourier_basis_coefs(dim, order)
#         Create Fourier basis coefficients for given dimension and order.
# ...

# %% [markdown]
# ## Eligibility Traces

# %%
from gym_classics2.algorithms import eligibility_traces
help(gym_classics2.algorithms.eligibility_traces)
# Out:
# Help on module gym_classics2.algorithms.eligibility_traces in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.eligibility_traces
#
# DESCRIPTION
#     This file implements the semi-gradient SARSA(lambda) algorithm for control with linear function approximation and eligibility traces.
#     The user needs to implement the state_features function to convert states to feature vectors.
#
# FUNCTIONS
#     active_weights(a, sf_len)
#         helper for q_hat()
#
#     semi_gradient_Sarsa_lambda(env, n, epsilon, alpha, gamma, lam, w=None, max_episode_length=1000, verbose=False, history=False)
#         Semi-gradient SARSA(lambda): on-policy control with linear function approximation
#         and eligibility traces.
#
#         Parameters
#         ----------
#         env : GymClassicsBaseEnv
#             Episodic environment used to generate experience.
#         n : int
#             Number of episodes.
#         epsilon : float
# ...

# %% [markdown]
# ## Policy Gradient Methods

# %%
from gym_classics2.algorithms import policy_gradient_methods
help(gym_classics2.algorithms.policy_gradient_methods)
# Out:
# Help on module gym_classics2.algorithms.policy_gradient_methods in gym_classics2.algorithms:
#
# NAME
#     gym_classics2.algorithms.policy_gradient_methods
#
# DESCRIPTION
#     This file implements policy gradient methods for learning parameterized policies.
#     The main algorithm implemented is REINFORCE, which is a Monte Carlo policy gradient method that updates policy
#     parameters based on the returns observed in sampled episodes. The policy is represented using a softmax function
#     over linear state-action features, and the algorithm estimates the policy gradient using the log-likelihood of actions taken
#     in the episodes. This implementation allows for learning stochastic policies that can handle exploration and exploitation in
#     reinforcement learning tasks.
#
#     The user has to overwrite the state_features function to convert state ids into feature vectors suitable for the environment
#     being used.
#
# FUNCTIONS
# ...
