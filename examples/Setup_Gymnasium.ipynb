# %% [markdown]
# # Setup Gymnasium
#
# The documentation for Gymnasium is available at https://gymnasium.farama.org/
#
# Steps:
# 1. Create a new folder and open it with VS Code and install all needed Python Extensions in VS Code.
# 2. Create a new virtual environment (CTRL-Shift P Python Create Environment...)
# 3. I needed to install swig and the Python C++ headers on WSL2 via the terminal
#     * `sudo apt install swig`
#     * `sudo apt-get install python3-dev`
# 4. Install python libraries for gymnasium with the needed extras

# %%
# %pip install swig
# %pip install gymnasium[box2d,classic_control]
# Out:
# Requirement already satisfied: swig in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (4.4.1)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium[box2d,classic_control] in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[box2d,classic_control]) (2.4.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[box2d,classic_control]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[box2d,classic_control]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[box2d,classic_control]) (0.0.4)
# Requirement already satisfied: box2d==2.3.10 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[box2d,classic_control]) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[box2d,classic_control]) (2.6.1)
# Requirement already satisfied: swig==4.* in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[box2d,classic_control]) (4.4.1)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Capturing Environment Visualizations in Notebooks
#
# Additional installs for screen capturing so environment visualizations can be converted to embedded videos.
# This also works on Google Colab so you can see the visualization.
#
# For recording videos, I had to install on WSL2:
#
# * `sudo apt-get install xvfb ffmpeg`

# %% [markdown]
# Additional python packages for screen capturing.

# %%
# %pip install pyvirtualdisplay
# %pip install gymnasium[other]
# Out:
# Requirement already satisfied: pyvirtualdisplay in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (3.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium[other] in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (2.4.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (0.0.4)
# Requirement already satisfied: moviepy>=1.0.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (2.2.1)
# Requirement already satisfied: matplotlib>=3.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (3.10.8)
# Requirement already satisfied: opencv-python>=3.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (4.13.0.92)
# Requirement already satisfied: seaborn>=0.13 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (26.0)
# Requirement already satisfied: pillow>=8 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]) (2.37.3)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]) (1.2.2)
# Requirement already satisfied: tqdm in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[other]) (4.67.3)
# Requirement already satisfied: six>=1.5 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[other]) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from seaborn>=0.13->gymnasium[other]) (3.0.2)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# &copy; 2025 [Michael Hahsler](http://michael.hahsler.net).
# This work is openly licensed under [Creative Commons Attribution-ShareAlike 4.0 International (CC BY-SA 4.0) License](https://creativecommons.org/licenses/by-sa/4.0/)
#
# ![CC BY-SA 4.0](https://licensebuttons.net/l/by-sa/3.0/88x31.png)
