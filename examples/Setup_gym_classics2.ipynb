# %% [markdown]
# # Setup `gym_classics2`
#
# This is a patched version of `gym_classic` originally by Brett Delay which we will use in class. Run the following code using your python environment to install the package.

# %%
# !git clone https://github.com/mhahsler/gym-classics2.git
# !cd gym-classics2; git pull
# !cd gym-classics; pip install -e .
# Out:
# fatal: destination path 'gym-classics' already exists and is not an empty directory.
# Already up to date.
# Obtaining file:///home/mhahsler/github/Introduction_to_Reinforcement_Learning/common/gym-classics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: gym-classics
#   Building editable for gym-classics (pyproject.toml) ... done
#   Created wheel for gym-classics: filename=gym_classics2-1.0.0+internal.rev1-0.editable-py3-none-any.whl size=21909 sha256=07f344dd81e8608ab6b06b04e031daea648be28ab09fd09e0cbc109d7d094790
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x9inlbzb/wheels/49/7b/bd/ecc930fd2c315727787b5898c40635de9f7e71db50d77712fc
# Successfully built gym-classics
# Installing collected packages: gym-classics
#   Attempting uninstall: gym-classics
#     Found existing installation: gym-classics 1.0.0+internal.rev1
#     Uninstalling gym-classics-1.0.0+internal.rev1:
#       Successfully uninstalled gym-classics-1.0.0+internal.rev1
# Successfully installed gym-classics-1.0.0+internal.rev1
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
