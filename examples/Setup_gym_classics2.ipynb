# %% [markdown]
# # Setup `gym_classics2`
#
# To install `gym_classics2`, you need already have installed Gymnasium. Here is how to do it: [Notebook to set up Gymnasium](Setup_Gymnasium.ipynb).

# %% [markdown]
# ## Setup via the Shell
#
# Activate the appropriate Python environment and run this in your shell.
#
# ```bash
# git clone https://github.com/mhahsler/gym-classics2.git
# cd gym-classics2
# git pull
# pip install -e .
# ```

# %% [markdown]
# ## Setup using Juptyer Notebooks/Colab
#
# Execute the cell below. To work with Colab, you need to copy the cell into your notebook.

# %%
# !git clone https://github.com/mhahsler/gym-classics2.git
# !cd gym-classics2; git pull; pip install -e .
# Out:
# Cloning into 'gym-classics2'...
# remote: Enumerating objects: 1010, done.
# remote: Counting objects: 100% (1010/1010), done.
# remote: Compressing objects: 100% (368/368), done.
# remote: Total 1010 (delta 679), reused 964 (delta 633), pack-reused 0 (from 0)
# Receiving objects: 100% (1010/1010), 1.00 MiB | 5.11 MiB/s, done.
# Resolving deltas: 100% (679/679), done.
# Already up to date.
# Obtaining file:///home/mhahsler/github/Introduction_to_Reinforcement_Learning/common/gym-classics2/examples/gym-classics2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for gym-classics2 (pyproject.toml) ... done
#   Created wheel for gym-classics2: filename=gym_classics2-1.0.0-0.editable-py3-none-any.whl size=17043 sha256=b2803ac6d5a14202efbc7154dcd42a7ec0636eeaa3e58bb4302552d44bdcc9d4
# ...
